# %% [markdown]
# # Downloading and loading the dataset

# %%
import numpy as np
import pandas as pd
df=pd.read_csv('US_Accidents_Dec20.csv')

# %% [markdown]
# # Data Preparation and Cleaning

# %%
df #Present the data inside the dataset
# Out:
#                 ID    Source    TMC  Severity           Start_Time  \
# 0              A-1  MapQuest  201.0         3  2016-02-08 05:46:00
# 1              A-2  MapQuest  201.0         2  2016-02-08 06:07:59
# 2              A-3  MapQuest  201.0         2  2016-02-08 06:49:27
# 3              A-4  MapQuest  201.0         3  2016-02-08 07:23:34
# 4              A-5  MapQuest  201.0         2  2016-02-08 07:39:07
# ...            ...       ...    ...       ...                  ...
# 4232536  A-4239402      Bing    NaN         2  2019-08-23 18:03:25
# 4232537  A-4239403      Bing    NaN         2  2019-08-23 19:11:30
# 4232538  A-4239404      Bing    NaN         2  2019-08-23 19:00:21
# 4232539  A-4239405      Bing    NaN         2  2019-08-23 19:00:21
# 4232540  A-4239406      Bing    NaN         2  2019-08-23 18:52:06
#
#                     End_Time  Start_Lat   Start_Lng   End_Lat    End_Lng  ...  \
# 0        2016-02-08 11:00:00  39.865147  -84.058723       NaN        NaN  ...
# ...

# %%
df.columns #To find the column labels/names
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance(mi)',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature(F)', 'Wind_Chill(F)', 'Humidity(%)', 'Pressure(in)',
#        'Visibility(mi)', 'Wind_Direction', 'Wind_Speed(mph)',
#        'Precipitation(in)', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
len(df.columns) #To find the number of columns
# Out:
# 49

# %%
len(df) #to find the number of rows
# Out:
# 4232541

# %%
df.info() #It gives information about the number of rows,columns,data types, and the usage of memory.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4232541 entries, 0 to 4232540
# Data columns (total 49 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Source                 object
#  2   TMC                    float64
#  3   Severity               int64
#  4   Start_Time             object
#  5   End_Time               object
#  6   Start_Lat              float64
#  7   Start_Lng              float64
#  8   End_Lat                float64
#  9   End_Lng                float64
#  10  Distance(mi)           float64
#  11  Description            object
#  12  Number                 float64
#  13  Street                 object
#  14  Side                   object
#  15  City                   object
#  16  County                 object
#  17  State                  object
#  18  Zipcode                object
#  19  Country                object
#  20  Timezone               object
# ...

# %%
df.describe() #It gives the statistics of all the numerical columns in the dataset.
# Out:
#                 TMC      Severity     Start_Lat     Start_Lng       End_Lat  \
# count  2.716477e+06  4.232541e+06  4.232541e+06  4.232541e+06  1.516064e+06
# mean   2.083517e+02  2.305035e+00  3.639782e+01 -9.546420e+01  3.690061e+01
# std    2.124413e+01  5.332261e-01  4.964404e+00  1.735319e+01  5.165629e+00
# min    2.000000e+02  1.000000e+00  2.455527e+01 -1.246238e+02  2.457011e+01
# 25%    2.010000e+02  2.000000e+00  3.352058e+01 -1.173570e+02  3.385420e+01
# 50%    2.010000e+02  2.000000e+00  3.582542e+01 -9.002078e+01  3.735134e+01
# 75%    2.010000e+02  3.000000e+00  4.018313e+01 -8.084682e+01  4.072593e+01
# max    4.060000e+02  4.000000e+00  4.900220e+01 -6.711317e+01  4.907500e+01
#
#             End_Lng  Distance(mi)        Number  Temperature(F)  \
# count  1.516064e+06  4.232541e+06  1.544592e+06    4.142641e+06
# mean  -9.859901e+01  3.357021e-01  6.141507e+03    6.147799e+01
# std    1.849590e+01  1.602143e+00  1.492268e+04    1.852586e+01
# ...

# %%
#Finding the number of numberic data columns in the dataset
numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
numeric_df = df.select_dtypes(include=numerics)
len(numeric_df.columns)
# Out:
# 15

# %%
df.isna() #to find the missing values
# Out:
#             ID  Source    TMC  Severity  Start_Time  End_Time  Start_Lat  \
# 0        False   False  False     False       False     False      False
# 1        False   False  False     False       False     False      False
# 2        False   False  False     False       False     False      False
# 3        False   False  False     False       False     False      False
# 4        False   False  False     False       False     False      False
# ...        ...     ...    ...       ...         ...       ...        ...
# 4232536  False   False   True     False       False     False      False
# 4232537  False   False   True     False       False     False      False
# 4232538  False   False   True     False       False     False      False
# 4232539  False   False   True     False       False     False      False
# 4232540  False   False   True     False       False     False      False
#
#          Start_Lng  End_Lat  End_Lng  ...  Roundabout  Station   Stop  \
# ...

# %%
df.isna().sum() #I t gives per column the count of missing values.
# Out:
# ID                             0
# Source                         0
# TMC                      1516064
# Severity                       0
# Start_Time                     0
# End_Time                       0
# Start_Lat                      0
# Start_Lng                      0
# End_Lat                  2716477
# End_Lng                  2716477
# Distance(mi)                   0
# Description                    2
# Number                   2687949
# Street                         0
# Side                           0
# City                         137
# County                         0
# State                          0
# Zipcode                     1292
# Country                        0
# Timezone                    4615
# Airport_Code                8973
# Weather_Timestamp          62644
# Temperature(F)             89900
# Wind_Chill(F)            1896001
# Humidity(%)                95467
# Pressure(in)               76384
# Visibility(mi)             98668
# ...

# %%
df.isna().sum().sort_values() #Sorting in ascending order
# Out:
# ID                             0
# Crossing                       0
# Give_Way                       0
# Junction                       0
# No_Exit                        0
# Railway                        0
# Roundabout                     0
# Station                        0
# Stop                           0
# Country                        0
# Traffic_Calming                0
# State                          0
# County                         0
# Bump                           0
# Side                           0
# Traffic_Signal                 0
# Distance(mi)                   0
# Turning_Loop                   0
# Start_Lng                      0
# Start_Lat                      0
# End_Time                       0
# Start_Time                     0
# Severity                       0
# Source                         0
# Street                         0
# Amenity                        0
# Description                    2
# City                         137
# ...

# %%
df.isna().sum().sort_values(ascending=False) #Sorting in descending order
# Out:
# End_Lat                  2716477
# End_Lng                  2716477
# Number                   2687949
# Precipitation(in)        2065589
# Wind_Chill(F)            1896001
# TMC                      1516064
# Wind_Speed(mph)           479326
# Visibility(mi)             98668
# Weather_Condition          98383
# Humidity(%)                95467
# Temperature(F)             89900
# Wind_Direction             83611
# Pressure(in)               76384
# Weather_Timestamp          62644
# Airport_Code                8973
# Timezone                    4615
# Zipcode                     1292
# Nautical_Twilight            141
# Astronomical_Twilight        141
# Civil_Twilight               141
# Sunrise_Sunset               141
# City                         137
# Description                    2
# Amenity                        0
# Street                         0
# Source                         0
# Severity                       0
# Start_Time                     0
# ...

# %%
#Percentage of missing values per column 
missing_percentage = df.isna().sum().sort_values(ascending=False)/len(df)
missing_percentage
# Out:
# End_Lat                  6.418076e-01
# End_Lng                  6.418076e-01
# Number                   6.350674e-01
# Precipitation(in)        4.880258e-01
# Wind_Chill(F)            4.479581e-01
# TMC                      3.581924e-01
# Wind_Speed(mph)          1.132478e-01
# Visibility(mi)           2.331176e-02
# Weather_Condition        2.324443e-02
# Humidity(%)              2.255548e-02
# Temperature(F)           2.124020e-02
# Wind_Direction           1.975433e-02
# Pressure(in)             1.804684e-02
# Weather_Timestamp        1.480057e-02
# Airport_Code             2.120003e-03
# Timezone                 1.090362e-03
# Zipcode                  3.052540e-04
# Nautical_Twilight        3.331332e-05
# Astronomical_Twilight    3.331332e-05
# Civil_Twilight           3.331332e-05
# Sunrise_Sunset           3.331332e-05
# City                     3.236826e-05
# Description              4.725294e-07
# Amenity                  0.000000e+00
# Street                   0.000000e+00
# ...

# %%
type(missing_percentage) #To find which type it is.
# Out:
# pandas.core.series.Series

# %%
missing_percentage.plot(kind='barh') #Plotting horizontal bar grpah.
# Out:
# <AxesSubplot:>

# %%
missing_percentage[missing_percentage!=0] #It only keeps the rows where we have true and removes all the 0's.
# Out:
# End_Lat                  6.418076e-01
# End_Lng                  6.418076e-01
# Number                   6.350674e-01
# Precipitation(in)        4.880258e-01
# Wind_Chill(F)            4.479581e-01
# TMC                      3.581924e-01
# Wind_Speed(mph)          1.132478e-01
# Visibility(mi)           2.331176e-02
# Weather_Condition        2.324443e-02
# Humidity(%)              2.255548e-02
# Temperature(F)           2.124020e-02
# Wind_Direction           1.975433e-02
# Pressure(in)             1.804684e-02
# Weather_Timestamp        1.480057e-02
# Airport_Code             2.120003e-03
# Timezone                 1.090362e-03
# Zipcode                  3.052540e-04
# Nautical_Twilight        3.331332e-05
# Astronomical_Twilight    3.331332e-05
# Civil_Twilight           3.331332e-05
# Sunrise_Sunset           3.331332e-05
# City                     3.236826e-05
# Description              4.725294e-07
# dtype: float64

# %%
missing_percentage[missing_percentage!=0].plot(kind='barh')
# Out:
# <AxesSubplot:>

# %%
df.City #We will get access to the city column
# Out:
# 0                Dayton
# 1          Reynoldsburg
# 2          Williamsburg
# 3                Dayton
# 4                Dayton
#                ...
# 4232536       Riverside
# 4232537       San Diego
# 4232538          Orange
# 4232539     Culver City
# 4232540        Highland
# Name: City, Length: 4232541, dtype: object

# %%
df.City.unique() #To get the unique cities
# Out:
# array(['Dayton', 'Reynoldsburg', 'Williamsburg', ..., 'Paron',
#        'Clarksdale', 'American Fork-Pleasant Grove'], dtype=object)

# %%
#To find number of unique cities
cities = df.City.unique()
len(cities)
# Out:
# 12251

# %%
cities[:100] #To print the first 100 unique cities
# Out:
# array(['Dayton', 'Reynoldsburg', 'Williamsburg', 'Westerville',
#        'Columbus', 'Miamisburg', 'Johnstown', 'Dublin',
#        'Canal Winchester', 'Lebanon', 'Sabina', 'Goshen', 'Waynesville',
#        'Springboro', 'Carroll', 'Oregonia', 'Independence',
#        'Maple Heights', 'Grove City', 'Findlay', 'Fairborn', 'Piqua',
#        'New Richmond', 'Batavia', 'Galena', 'Barberton', 'Akron',
#        'Mansfield', 'Cleveland', 'Bethel', 'Pataskala', 'Seville',
#        'Bellville', 'Troy', 'Wilmington', 'North Olmsted', 'Groveport',
#        'Orient', 'Tiro', 'Strongsville', 'Beavercreek', 'Circleville',
#        'Peebles', 'Hurricane', 'Xenia', 'Elyria', 'Pickerington',
#        'Burbank', 'Zanesville', 'North Baltimore', 'Mount Sterling',
#        'Tipp City', 'Moraine', 'Hilliard', 'Bowling Green', 'Maineville',
#        'Vermilion', 'Milford', 'Brookpark', 'Fraziers Bottom',
#        'Cambridge', 'Delaware', 'Moscow', 'Oberlin', 'Sardinia',
# ...

# %%
#Total number of accidents in each city
cities_by_accident = df.City.value_counts()
cities_by_accident
# Out:
# Houston        114905
# Los Angeles     92701
# Charlotte       88887
# Dallas          77303
# Austin          70538
#                 ...
# Alder Creek         1
# Florala             1
# Dugspur             1
# South Solon         1
# Heavener            1
# Name: City, Length: 12250, dtype: int64

# %%
#Top 20 cities where more accidents occured
cities_by_accident[:20]
# Out:
# Houston          114905
# Los Angeles       92701
# Charlotte         88887
# Dallas            77303
# Austin            70538
# Miami             63162
# Raleigh           52876
# Atlanta           46328
# Baton Rouge       42814
# Nashville         41850
# Orlando           39561
# Oklahoma City     39484
# Sacramento        38061
# Phoenix           32805
# Minneapolis       31781
# San Diego         29416
# Seattle           28004
# Richmond          27907
# San Antonio       27516
# Jacksonville      24009
# Name: City, dtype: int64

# %%
'New York' in df.City #It checks whether the newyork is present in the cities list or not.
# Out:
# False

# %%
df.State #access the state column
# Out:
# 0          OH
# 1          OH
# 2          OH
# 3          OH
# 4          OH
#            ..
# 4232536    CA
# 4232537    CA
# 4232538    CA
# 4232539    CA
# 4232540    CA
# Name: State, Length: 4232541, dtype: object

# %%
'NY' in df.State #check whether new york is presnt in state column or not
# Out:
# False

# %%
cities_by_accident[:20].plot(kind='barh') #Plotting the horizontal bargraph of cities by accidents
# Out:
# <AxesSubplot:>

# %%
list(cities_by_accident) #We get the list of numbers
# Out:
# [114905,
#  92701,
#  88887,
#  77303,
#  70538,
#  63162,
#  52876,
#  46328,
#  42814,
#  41850,
#  39561,
#  39484,
#  38061,
#  32805,
#  31781,
#  29416,
#  28004,
#  27907,
#  27516,
#  24009,
#  23830,
#  23707,
#  22956,
#  22952,
#  22479,
#  22463,
#  21535,
#  21364,
#  20022,
#  19504,
#  18195,
#  18055,
#  17345,
#  17082,
#  16490,
#  16437,
#  16008,
#  15769,
#  15234,
#  15105,
#  14399,
#  14008,
#  13712,
#  13593,
#  13278,
#  12826,
#  12788,
#  12483,
#  12471,
#  12374,
#  12353,
#  11223,
#  11087,
#  10944,
#  10761,
#  10657,
#  10621,
#  10430,
#  10304,
#  10255,
#  9986,
#  9983,
#  9508,
#  9430,
#  9342,
#  9087,
#  9050,
#  9014,
#  8594,
#  8593,
#  8369,
#  8001,
#  7902,
#  7894,
#  7877,
#  7775,
#  7701,
#  7558,
#  7400,
#  7213,
#  7144,
#  7054,
#  7053,
#  7027,
#  6923,
#  6840,
#  6684,
#  6522,
#  6506,
#  6376,
#  6358,
#  6308,
#  6295,
#  6248,
#  6235,
#  6234,
#  6218,
#  6185,
#  6169,
#  6113,
#  6089,
#  6015,
#  5959,
#  5897,
# ...

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
sns.distplot(cities_by_accident) #Most cities have less than 2000 accidents
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
#assigning the count of the high accident and low accident cities
high_accident_cities = cities_by_accident[cities_by_accident>=1000]
low_accident_cities = cities_by_accident[cities_by_accident<1000]

# %%
#count of high accident cities
len(high_accident_cities)
# Out:
# 704

# %%
#percentage of high accident cities
len(high_accident_cities)/len(cities)
# Out:
# 0.05746469675944821

# %%
sns.distplot(high_accident_cities)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
sns.distplot(low_accident_cities)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='City', ylabel='Density'>

# %%
#Most cities have more number of accidents between 0 and 100
sns.histplot(cities_by_accident, log_scale=True)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Count'>

# %%
#The cities which are havving only 1 accident.
cities_by_accident[cities_by_accident==1]
# Out:
# Wye Mills         1
# Salmon            1
# Ecorse            1
# Charleston AFB    1
# Cochecton         1
#                  ..
# Alder Creek       1
# Florala           1
# Dugspur           1
# South Solon       1
# Heavener          1
# Name: City, Length: 1267, dtype: int64

# %%
df.Start_Time #Displays the start time
# Out:
# 0          2016-02-08 05:46:00
# 1          2016-02-08 06:07:59
# 2          2016-02-08 06:49:27
# 3          2016-02-08 07:23:34
# 4          2016-02-08 07:39:07
#                   ...
# 4232536    2019-08-23 18:03:25
# 4232537    2019-08-23 19:11:30
# 4232538    2019-08-23 19:00:21
# 4232539    2019-08-23 19:00:21
# 4232540    2019-08-23 18:52:06
# Name: Start_Time, Length: 4232541, dtype: object

# %%
pd.to_datetime(df.Start_Time) #Converting to date time
# Out:
# 0         2016-02-08 05:46:00
# 1         2016-02-08 06:07:59
# 2         2016-02-08 06:49:27
# 3         2016-02-08 07:23:34
# 4         2016-02-08 07:39:07
#                   ...
# 4232536   2019-08-23 18:03:25
# 4232537   2019-08-23 19:11:30
# 4232538   2019-08-23 19:00:21
# 4232539   2019-08-23 19:00:21
# 4232540   2019-08-23 18:52:06
# Name: Start_Time, Length: 4232541, dtype: datetime64[ns]

# %%
#Modifying the column and printing the value
df.Start_Time=pd.to_datetime(df.Start_Time)
df.Start_Time
# Out:
# 0         2016-02-08 05:46:00
# 1         2016-02-08 06:07:59
# 2         2016-02-08 06:49:27
# 3         2016-02-08 07:23:34
# 4         2016-02-08 07:39:07
#                   ...
# 4232536   2019-08-23 18:03:25
# 4232537   2019-08-23 19:11:30
# 4232538   2019-08-23 19:00:21
# 4232539   2019-08-23 19:00:21
# 4232540   2019-08-23 18:52:06
# Name: Start_Time, Length: 4232541, dtype: datetime64[ns]

# %%
#Gives the hour value in the first value 0f the starttime column
df.Start_Time[0].hour
# Out:
# 5

# %%
#To get the hour of all the timestamps in the column
df.Start_Time.dt.hour
# Out:
# 0           5
# 1           6
# 2           6
# 3           7
# 4           7
#            ..
# 4232536    18
# 4232537    19
# 4232538    19
# 4232539    19
# 4232540    18
# Name: Start_Time, Length: 4232541, dtype: int64

# %%
sns.histplot(df.Start_Time.dt.hour)
# Out:
# <AxesSubplot:xlabel='Start_Time', ylabel='Count'>

# %%
#There were more number of accidents happended in the morning 8 am
sns.histplot(df.Start_Time.dt.hour,bins=24)
# Out:
# <AxesSubplot:xlabel='Start_Time', ylabel='Count'>

# %%
#Plotting the Percentages of accidents
sns.distplot(df.Start_Time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
#Highest number of accidents occured in which day of a week.
sns.distplot(df.Start_Time.dt.dayofweek,bins=7,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
#At which time highest number of accidents are occuring in sunday
sundays_start_time = df.Start_Time[df.Start_Time.dt.dayofweek==6]
sns.distplot(sundays_start_time.dt.hour,bins=24,kde=False,norm_hist=True)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
#occuring of accidents on every sunday on every month
sns.distplot(sundays_start_time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# <AxesSubplot:xlabel='Start_Time'>

# %%
df.Start_Time.dt.year
# Out:
# 0          2016
# 1          2016
# 2          2016
# 3          2016
# 4          2016
#            ...
# 4232536    2019
# 4232537    2019
# 4232538    2019
# 4232539    2019
# 4232540    2019
# Name: Start_Time, Length: 4232541, dtype: int64

# %%
#checking the number of accidents for the year 2019
df_2019 = df[df.Start_Time.dt.year==2019]
sns.distplot(df_2019.Start_Time.dt.month,bins=12,kde=False,norm_hist=True)
# Out:
# D:\Anaconda\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Start_Time'>

# %%
#Fom which source the data comes
df.Source
# Out:
# 0          MapQuest
# 1          MapQuest
# 2          MapQuest
# 3          MapQuest
# 4          MapQuest
#              ...
# 4232536        Bing
# 4232537        Bing
# 4232538        Bing
# 4232539        Bing
# 4232540        Bing
# Name: Source, Length: 4232541, dtype: object

# %%
#Plotting a pie chart
df.Source.value_counts().plot(kind='pie')
# Out:
# <AxesSubplot:ylabel='Source'>

# %%
#Values present in the Latitue column
df.Start_Lat
# Out:
# 0          39.865147
# 1          39.928059
# 2          39.063148
# 3          39.747753
# 4          39.627781
#              ...
# 4232536    34.002480
# 4232537    32.766960
# 4232538    33.775450
# 4232539    33.992460
# 4232540    34.133930
# Name: Start_Lat, Length: 4232541, dtype: float64

# %%
#Values present in the Longitude column
df.Start_Lng
# Out:
# 0          -84.058723
# 1          -82.831184
# 2          -84.032608
# 3          -84.205582
# 4          -84.188354
#               ...
# 4232536   -117.379360
# 4232537   -117.148060
# 4232538   -117.847790
# 4232539   -118.403020
# 4232540   -117.230920
# Name: Start_Lng, Length: 4232541, dtype: float64

# %%
sns.scatterplot(x=df.Start_Lng, y=df.Start_Lat)
# Out:
# <AxesSubplot:xlabel='Start_Lng', ylabel='Start_Lat'>

# %%
pip install folium
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Shows the world Map
import folium
folium.Map()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
#Locating one particular location in a map
lat,lon=df.Start_Lat[0],df.Start_Lng[0]
lat,lon
# Out:
# (39.865147, -84.058723)

# %%
map = folium.Map()
marker = folium.Marker((lat,lon))
marker.add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...

# %%
from folium.plugins import HeatMap

# %%
#Zip all the latitudes and longitudes
zip(list(df.Start_Lat),list(df.Start_Lng))

# %%
#It gives the list of all latitudes and longitudes
list(zip(list(df.Start_Lat),list(df.Start_Lng)))
# Out:
# [(39.865147, -84.058723),
#  (39.928059000000005, -82.831184),
#  (39.063148, -84.032608),
#  (39.747753, -84.20558199999999),
#  (39.627781, -84.188354),
#  (40.100590000000004, -82.92519399999999),
#  (39.758274, -84.23050699999999),
#  (39.770382, -84.194901),
#  (39.778061, -84.172005),
#  (40.100590000000004, -82.92519399999999),
#  (39.952812, -83.119293),
#  (39.932709, -82.83091),
#  (39.737633, -84.14993299999999),
#  (39.79076, -84.241547),
#  (39.972038, -82.913521),
#  (39.745888, -84.17041),
#  (39.748329, -84.224007),
#  (39.752174, -84.239952),
#  (39.740669, -84.184135),
#  (39.790703, -84.244461),
#  (40.052509, -82.88233199999999),
#  (39.773346000000004, -84.224686),
#  (39.628288, -84.226151),
#  (40.023487, -82.994888),
#  (39.761379, -84.25921600000001),
#  (40.158024, -82.641762),
#  (39.733219, -84.159653),
#  (39.775303, -84.200523),
#  (39.789322, -84.23910500000001),
#  (39.758720000000004, -84.183762),
#  (40.081459, -83.122398),
# ...

# %%
map = folium.Map()
HeatMap(zip(list(df.Start_Lat),list(df.Start_Lng))).add_to(map)

# %%
sample_df = df.sample(int(0.01*len(df)))
lat_lon_pairs = list(zip(list(sample_df.Start_Lat),list(sample_df.Start_Lng)))

# %%
map = folium.Map()
HeatMap(lat_lon_pairs).add_to(map)
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript
# ...
